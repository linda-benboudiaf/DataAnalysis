# %%
import pandas as pd
food_info = pd.read_csv('food_info.csv')
food_info
print(food_info.columns)
# Out:
# Index(['NDB_No', 'Shrt_Desc', 'Water_(g)', 'Energ_Kcal', 'Protein_(g)',
#        'Lipid_Tot_(g)', 'Ash_(g)', 'Carbohydrt_(g)', 'Fiber_TD_(g)',
#        'Sugar_Tot_(g)', 'Calcium_(mg)', 'Iron_(mg)', 'Magnesium_(mg)',
#        'Phosphorus_(mg)', 'Potassium_(mg)', 'Sodium_(mg)', 'Zinc_(mg)',
#        'Copper_(mg)', 'Manganese_(mg)', 'Selenium_(mcg)', 'Vit_C_(mg)',
#        'Thiamin_(mg)', 'Riboflavin_(mg)', 'Niacin_(mg)', 'Vit_B6_(mg)',
#        'Vit_B12_(mcg)', 'Vit_A_IU', 'Vit_A_RAE', 'Vit_E_(mg)', 'Vit_D_mcg',
#        'Vit_D_IU', 'Vit_K_(mcg)', 'FA_Sat_(g)', 'FA_Mono_(g)', 'FA_Poly_(g)',
#        'Cholestrl_(mg)'],
#       dtype='object')

# %%
row_100 = food_info.loc[99]

# %% [markdown]
# ### Conversion et operations mathématique sur le dataset

# %%
i = food_info.shape[0]
five_last_rows = food_info.loc[i-5 : i-1]
five_last_rows
five_last = food_info.tail()

protein = food_info["Protein_(g)"]
cholesterol = food_info["Cholestrl_(mg)"]

#print(protein)
#print(cholesterol)
col = ['Shrt_Desc', 'Thiamin_(mg)', 'Selenium_(mcg)']
selenuim_thiamin = food_info[col]
print(type(food_info.columns.tolist()))
grams = []
for i in food_info.columns.tolist():
    if i.endswith("(g)"):
        grams.append(i)
        
food_info[grams]

sodium_grams = food_info['Sodium_(mg)'] / 1000
#print(sodium_grams)
sugar_miligrams = food_info['Sugar_Tot_(g)'] * 1000
#print(sugar_miligrams)
# Out:
# <class 'list'>

# %%
grams_of_proteine_per_grams_of_water = food_info['Protein_(g)'] / food_info['Water_(g)']
miligrams_of_calcium_and_iron = food_info['Calcium_(mg)'] + food_info['Iron_(mg)']

## Calcul d'indice nutritionel. 
proteine = food_info['Protein_(g)'] * 2
fat = food_info['Lipid_Tot_(g)'] * (-0.75)
rating = proteine + fat
#print(rating)

# %% [markdown]
# ### Normalisation de la données.

# %%
# Normalisation de la données proteine et lipid. 

normalized_protein = food_info['Protein_(g)']/ food_info['Protein_(g)'].max()
normalized_fat = food_info['Lipid_Tot_(g)']/ food_info['Lipid_Tot_(g)'].max()

#print(normalized_protein)
#print(normalized_fat)

food_info['Normalized_Protein'] = normalized_protein
food_info['Normalized_fat'] = normalized_fat
# Out:
#    NDB_No                 Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001          BUTTER WITH SALT      15.87         717         0.85
# 1    1002  BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2    1003      BUTTER OIL ANHYDROUS       0.24         876         0.28
# 3    1004               CHEESE BLUE      42.41         353        21.40
# 4    1005              CHEESE BRICK      41.11         371        23.24
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  ...  \
# 0          81.11     2.11            0.06           0.0           0.06  ...
# 1          81.11     2.11            0.06           0.0           0.06  ...
# 2          99.48     0.00            0.00           0.0           0.00  ...
# 3          28.74     5.11            2.34           0.0           0.50  ...
# 4          29.68     3.18            2.79           0.0           0.51  ...
#
#    Vit_E_(mg)  Vit_D_mcg  Vit_D_IU  Vit_K_(mcg)  FA_Sat_(g)  FA_Mono_(g)  \
# ...

# %%
food_info['Norm_Nutr_index'] = food_info['Normalized_Protein'] * 2 + (-0.75) * food_info['Normalized_fat']

# %% [markdown]
# ### Trier un Dataframe

# %%
# sort_values("column_name")
food_info.sort_values("Norm_Nutr_index", inplace=True, ascending = False)
food_info.head()
# Out:
#       NDB_No                                         Shrt_Desc  Water_(g)  \
# 4991   16423          SOY PROT ISOLATE K TYPE CRUDE PROT BASIS       4.98
# 6155   19177                          GELATINS DRY PDR UNSWTND      13.00
# 216     1258            EGG WHITE DRIED STABILIZED GLUCOSE RED       6.53
# 124     1136        EGG WHITE DRIED PDR STABILIZED GLUCOSE RED       8.54
# 8152   35055  SEAL BEARDED (OOGRUK) MEAT DRIED (ALASKA NATIVE)      11.60
#
#       Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# 4991         321        88.32           0.53     3.58            2.59
# 6155         335        85.60           0.10     1.30            0.00
# 216          362        84.63           0.48     3.63            4.72
# 124          376        82.40           0.04     4.55            4.47
# 8152         351        82.60           2.30     3.50            0.00
#
#       Fiber_TD_(g)  Sugar_Tot_(g)  ...  Vit_D_mcg  Vit_D_IU  Vit_K_(mcg)  \
# ...
